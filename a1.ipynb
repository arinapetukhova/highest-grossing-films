# %% [markdown]
# ## Web-Scraping of the Wikipedia page using BeautifulSoup

# %%
# Importing necessary libraries
from bs4 import BeautifulSoup
import requests
from concurrent.futures import ThreadPoolExecutor
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, REAL, TEXT, INTEGER
from sqlalchemy.orm import sessionmaker
import json
import re

BASE_URL = 'https://en.wikipedia.org' # Base URL of Wikipedia
HEADERS = {'User-Agent': 'Mozilla/5.0'} # Headers to simulate a browser visit

# Sending GET request to the Wikipedia page containing the list of highest-grossing films
response = requests.get(BASE_URL + '/wiki/List_of_highest-grossing_films', headers=HEADERS)
soup = BeautifulSoup(response.content, "lxml") # BeautifulSoup object for parsing the data
data = [] # Empty list to hold the films data

# Finding the necessary table with the data that's needed and creating variables to hold some data-related values
table = soup.findAll('table', {'class': 'wikitable plainrowheaders'})[1]
prev_year = 0
film_links = []

# Iterating through necessary rows in the table
for row in table.findAll("tr")[1:-1]:
    # Extracting Film Title, Box Office, Budget
    columns = row.find_all('td')[:3]
    # Trimming and storing text values from the selected columns
    cols = [ele.text.strip() for ele in columns]

    # Handling of specific problems related to some titles/years
    if cols[0] == "Harry Potter and the Philosopher's Stone" or cols[0] == "Snow White and the Seven Dwarfs":
        cols[1] = cols[1].split("(")[0].strip()[:-2]

    if cols[0] == "Harry Potter and the Deathly Hallows \u2013 Part 2":
        cols[2] = cols[2][:-1]

    if row.find('th') is not None:
        year = row.find('th').text.strip()
        cols.append(year)
        prev_year = year
    else:
        cols.append(prev_year)

    # Finding the link to the film's details and storing it
    new_href = columns[0].find('a', href=True)
    if new_href:
        film_links.append(new_href['href'])
    
    # Appending the gathered columns data to the data list
    data.append(cols)

# Function to scrape film details from the individual film page
def scrape_film_details(link):
    film_data = [] # List to store the film's details
    # New request (to parse the film's personal page)
    response2 = requests.get(BASE_URL + link, headers=HEADERS)
    soup2 = BeautifulSoup(response2.content, 'lxml')
    # Finding the table with necessary data
    table_film_related = soup2.find('table', {'class': 'infobox vevent'})
    
    # Extracting the director's name
    if table_film_related:
        director = table_film_related.find_all('tr')[2].find('td').text.strip()
        ind = 0
        # Handling of specific problems related to some director values
        if (len(director) == 0) or ("Directed" not in table_film_related.find_all('tr')[2].find('th').text.strip()):
            for part in table_film_related.find_all('tr'):
                th_element = part.find('th')
                if th_element is not None:
                    th_text = th_element.text.strip()
                    if "Directed" in th_text:
                        break
                ind += 1
            director = table_film_related.find_all('tr')[ind].find('td').text.strip() 

        # Appending the director's name to the film data
        film_data.append(director)

        # Extracting the country
        country_row_index = len(table_film_related.find_all('tr')) - 4
        country = table_film_related.find_all('tr')[country_row_index].find('td').text.strip()

        # Handling of specific problems related to some country values
        if len(country.split()) >= 2 and country.split()[1] == 'minutes':
            country_row_index = len(table_film_related.find_all('tr')) - 3
            country = table_film_related.find_all('tr')[country_row_index].find('td').text.strip()
        
        # Appending the country to the film data
        film_data.append(country)

    return film_data

# Using ThreadPoolExecutor to make concurrent requests (to make the process of parsing faster)
with ThreadPoolExecutor(max_workers=5) as executor:
    film_details = list(executor.map(scrape_film_details, film_links))

# Combination of the collected details (director's name, country) with the original data (title, box office, budget)
for index, details in enumerate(film_details):
    if index < len(data):
        data[index].extend(details)

# Function to clean a string by removing specified parts
def clean_string(original_string, parts_to_remove):
    cleaned_string = original_string
    for part in parts_to_remove:
        cleaned_string = cleaned_string.replace(part, '')
    cleaned_string = cleaned_string.strip()
    return cleaned_string

# Function to format the director names appropriately
def director_format_fix(str, last_names, words_to_remove):
    final = []
    str = clean_string(str, words_to_remove)
    f = False
    if str == "John FordMervyn LeRoyJoshua Logan":
        return "John Ford\nMervyn LeRoy\nJoshua Logan"
    for part in str.split('\n'):
        f = False
        for name in last_names:
            if name in part:
                f = True
                break
        if not f:
            final.append(re.sub(r'(?<=[a-z.])(?=[A-Z])', '\n', re.sub(r"\[.*?\]", '', part)))
        else:
            final.append(part)
    return '\n'.join(final)

# Words to remove from director descriptions
words_to_remove = ['British & French:', 'American:', 'German:', '(action sequences)',
                   '(uncredited)', 'Live action:', 'Animation:', 'Dialogue directors:', '[1]',
                   'Supervising Directors', 'Sequence Directors',
                   'Uncredited:', 'Supervising Director', 'Sequence Director']
# Words to keep unchanged in director descriptions
last_names = ['McCarey', 'DeMille', 'LeRoy', 'McTiernan']
structured_data = [] # List to hold structured data for each film

# Iterating over the collected data to clean, structure it, and store in the structured_data list
for item in data:
    if len(item) >= 6:
        film_record = {
            "title": item[0],
            "box_office": float(re.sub(r'[^0-9.]', '', re.split(r'[–/(\s]', item[1])[0])),
            "budget": float(re.sub(r'[^0-9.]', '', re.split(r'[–/(\s]', item[2])[0])),
            "release_year": int(item[3]),
            "director": director_format_fix(item[4], last_names, words_to_remove),
            "country": re.sub(r'(?<=[a-z])(?=[A-Z])', '\n', re.sub(r"\[.*?\]", '', item[5]))
        }
        structured_data.append(film_record)
# Out:
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_8103/691294321.py:21: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   table = soup.findAll('table', {'class': 'wikitable plainrowheaders'})[1]
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_8103/691294321.py:26: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   for row in table.findAll("tr")[1:-1]:

# %% [markdown]
# ## Creation of the database using SQLAlchemy

# %%
# Setting up SQLAlchemy to create a SQLite database
engine = create_engine('sqlite:///highest-grossing_films.db', echo=True)
Base = declarative_base()

# Defining Film class mapping to the film table
class Film(Base):
    __tablename__ = 'films_data'
    id = Column(INTEGER, primary_key=True, autoincrement=True)
    title = Column(TEXT)
    release_year = Column(INTEGER)
    director = Column(TEXT)
    box_office = Column(REAL)
    budget = Column(REAL)
    country = Column(TEXT)

    # Method to represent the Film object in a readable format
    def __repr__(self):
        return "<Film(title='%s', director='%s', year='%s')>" % (self.title, self.director, self.release_year)

# Creating the table in the database
Base.metadata.create_all(engine)

# Create a session
Session = sessionmaker(bind=engine)
session = Session()

# Delete any existing records from the table (to avoid duplicates)
session.query(Film).delete()

# Adding each structured film record to the session
for w in structured_data:
    session.add(Film(**w))

# Committing the changes to the database
session.commit()
# Out:
# 2025-02-25 00:38:06,759 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-25 00:38:06,760 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("films_data")
# 2025-02-25 00:38:06,760 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-02-25 00:38:06,761 INFO sqlalchemy.engine.Engine COMMIT
# 2025-02-25 00:38:06,763 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-25 00:38:06,764 INFO sqlalchemy.engine.Engine DELETE FROM films_data
# 2025-02-25 00:38:06,764 INFO sqlalchemy.engine.Engine [generated in 0.00033s] ()
# 2025-02-25 00:38:06,770 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,770 INFO sqlalchemy.engine.Engine [generated in 0.00036s] ('The Birth of a Nation', 1915, 'D. W. Griffith', 50000000.0, 110000.0, 'United States')
# 2025-02-25 00:38:06,771 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,771 INFO sqlalchemy.engine.Engine [cached since 0.001045s ago] ('Intolerance', 1916, 'D. W. Griffith', 1750000.0, 385907.0, 'United States')
# 2025-02-25 00:38:06,771 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,772 INFO sqlalchemy.engine.Engine [cached since 0.00165s ago] ('Cleopatra', 1917, 'J. Gordon Edwards', 500000.0, 300000.0, 'United States')
# 2025-02-25 00:38:06,772 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,772 INFO sqlalchemy.engine.Engine [cached since 0.002095s ago] ('Mickey', 1918, 'F. Richard Jones\nJames Young', 8000000.0, 250000.0, 'United States')
# 2025-02-25 00:38:06,772 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,773 INFO sqlalchemy.engine.Engine [cached since 0.002635s ago] ('The Miracle Man', 1919, 'George Loane Tucker', 3000000.0, 120000.0, 'United States')
# 2025-02-25 00:38:06,773 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,773 INFO sqlalchemy.engine.Engine [cached since 0.003024s ago] ('Way Down East', 1920, 'D. W. Griffith', 5000000.0, 800000.0, 'United States')
# 2025-02-25 00:38:06,773 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,774 INFO sqlalchemy.engine.Engine [cached since 0.003674s ago] ('The Four Horsemen of the Apocalypse', 1921, 'Rex Ingram', 5000000.0, 600000.0, 'United States')
# 2025-02-25 00:38:06,774 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,774 INFO sqlalchemy.engine.Engine [cached since 0.004306s ago] ('Douglas Fairbanks in Robin Hood', 1922, 'Allan Dwan', 2500000.0, 930042.78, 'United States')
# 2025-02-25 00:38:06,775 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,775 INFO sqlalchemy.engine.Engine [cached since 0.004817s ago] ('The Covered Wagon', 1923, 'James Cruze', 5000000.0, 800000.0, 'United States')
# 2025-02-25 00:38:06,775 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,776 INFO sqlalchemy.engine.Engine [cached since 0.005648s ago] ('The Sea Hawk', 1924, 'Frank Lloyd', 3000000.0, 700000.0, 'United States')
# 2025-02-25 00:38:06,776 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,777 INFO sqlalchemy.engine.Engine [cached since 0.006559s ago] ('The Big Parade', 1925, 'King Vidor', 18000000.0, 382000.0, 'United States')
# 2025-02-25 00:38:06,777 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,777 INFO sqlalchemy.engine.Engine [cached since 0.007337s ago] ('Ben-Hur', 1925, 'Fred Niblo\n\nCharles Brabin', 10738000.0, 3967000.0, 'United States')
# 2025-02-25 00:38:06,779 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,779 INFO sqlalchemy.engine.Engine [cached since 0.008695s ago] ("For Heaven's Sake", 1926, 'Sam Taylor', 2600000.0, 150000.0, 'United States')
# 2025-02-25 00:38:06,779 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,780 INFO sqlalchemy.engine.Engine [cached since 0.009571s ago] ('Wings', 1927, 'William A. Wellman', 3600000.0, 2000000.0, 'United States')
# 2025-02-25 00:38:06,780 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,780 INFO sqlalchemy.engine.Engine [cached since 0.01021s ago] ('The Singing Fool', 1928, 'Lloyd Bacon', 5900000.0, 388000.0, 'United States')
# 2025-02-25 00:38:06,781 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,781 INFO sqlalchemy.engine.Engine [cached since 0.01074s ago] ('The Broadway Melody', 1929, 'Harry Beaumont', 4400000.0, 379000.0, 'United States')
# 2025-02-25 00:38:06,781 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,781 INFO sqlalchemy.engine.Engine [cached since 0.01123s ago] ('Sunny Side Up', 1929, 'David Butler', 3500000.0, 600000.0, 'United States')
# 2025-02-25 00:38:06,782 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,782 INFO sqlalchemy.engine.Engine [cached since 0.01162s ago] ('All Quiet on the Western Front', 1930, 'Lewis Milestone', 3000000.0, 1250000.0, 'United States')
# 2025-02-25 00:38:06,782 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,782 INFO sqlalchemy.engine.Engine [cached since 0.012s ago] ('Frankenstein', 1931, 'James Whale', 12000000.0, 250000.0, 'United States')
# 2025-02-25 00:38:06,783 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,783 INFO sqlalchemy.engine.Engine [cached since 0.01276s ago] ('City Lights', 1931, 'Charlie Chaplin', 5000000.0, 1607351.0, 'United States')
# 2025-02-25 00:38:06,783 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,783 INFO sqlalchemy.engine.Engine [cached since 0.01331s ago] ('The Sign of the Cross', 1932, 'Cecil B. DeMille', 2738993.0, 694065.0, 'United States')
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine [cached since 0.01368s ago] ('King Kong', 1933, 'Merian C. Cooper\nErnest B. Schoedsack', 5347000.0, 672255.75, 'United States')
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine [cached since 0.01402s ago] ("I'm No Angel", 1933, 'Wesley Ruggles', 3250000.0, 200000.0, 'United States')
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,784 INFO sqlalchemy.engine.Engine [cached since 0.01433s ago] ('Cavalcade', 1933, 'Frank Lloyd', 3000000.0, 1116000.0, 'United States')
# 2025-02-25 00:38:06,785 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,785 INFO sqlalchemy.engine.Engine [cached since 0.01479s ago] ('She Done Him Wrong', 1933, 'Lowell Sherman', 3000000.0, 274076.0, 'United States')
# 2025-02-25 00:38:06,785 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,785 INFO sqlalchemy.engine.Engine [cached since 0.01524s ago] ('The Merry Widow', 1934, 'Ernst Lubitsch', 2608000.0, 1605000.0, 'United States')
# 2025-02-25 00:38:06,786 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,786 INFO sqlalchemy.engine.Engine [cached since 0.0156s ago] ('It Happened One Night', 1934, 'Frank Capra', 2500000.0, 325000.0, 'United States')
# 2025-02-25 00:38:06,786 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,786 INFO sqlalchemy.engine.Engine [cached since 0.01599s ago] ('Mutiny on the Bounty', 1935, 'Frank Lloyd', 4460000.0, 1905000.0, 'United States')
# 2025-02-25 00:38:06,786 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,787 INFO sqlalchemy.engine.Engine [cached since 0.01644s ago] ('San Francisco', 1936, 'W. S. Van Dyke', 6044000.0, 1300000.0, 'United States')
# 2025-02-25 00:38:06,787 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,787 INFO sqlalchemy.engine.Engine [cached since 0.01686s ago] ('Snow White and the Seven Dwarfs', 1937, 'David Hand\n\nPerce Pearce\nWilliam Cottrell\nLarry Morey\nWilfred Jackson\nBen Sharpsteen', 418000000.0, 1488423.0, 'United States')
# 2025-02-25 00:38:06,787 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,787 INFO sqlalchemy.engine.Engine [cached since 0.01732s ago] ("You Can't Take It with You", 1938, 'Frank Capra', 5000000.0, 1200000.0, 'United States')
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine [cached since 0.0177s ago] ('Gone with the Wind', 1939, 'Victor Fleming', 390525192.0, 3900000.0, 'United States')
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine [cached since 0.01808s ago] ('Pinocchio', 1940, 'Ben Sharpsteen\nHamilton Luske\n\n\nBill Roberts\nNorman Ferguson\nJack Kinney\nWilfred Jackson\nT. Hee', 87000862.0, 2600000.0, 'United States')
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,788 INFO sqlalchemy.engine.Engine [cached since 0.01841s ago] ('Boom Town', 1940, 'Jack Conway', 4600000.0, 2100000.0, 'United States')
# 2025-02-25 00:38:06,789 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,789 INFO sqlalchemy.engine.Engine [cached since 0.01877s ago] ('Sergeant York', 1941, 'Howard Hawks', 7800000.0, 1600000.0, 'United States')
# 2025-02-25 00:38:06,789 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,789 INFO sqlalchemy.engine.Engine [cached since 0.01917s ago] ('Bambi', 1942, 'David D. Hand\n\nJames Algar\nBill Roberts\nNorman Wright\nSam Armstrong\nPaul Satterfield\nGraham Heid', 267997843.0, 1700000.0, 'United States')
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine [cached since 0.01958s ago] ('Mrs. Miniver', 1942, 'William Wyler', 8878000.0, 1344000.0, 'United States')
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine [cached since 0.01992s ago] ('For Whom the Bell Tolls', 1943, 'Sam Wood', 11000000.0, 2681298.0, 'United States')
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,790 INFO sqlalchemy.engine.Engine [cached since 0.02024s ago] ('This Is the Army', 1943, 'Michael Curtiz\nHugh Cummings\nEdward A. Blatt', 9555586.44, 1400000.0, 'United States')
# 2025-02-25 00:38:06,791 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,791 INFO sqlalchemy.engine.Engine [cached since 0.02067s ago] ('Going My Way', 1944, 'Leo McCarey', 6500000.0, 1000000.0, 'United States')
# 2025-02-25 00:38:06,791 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,791 INFO sqlalchemy.engine.Engine [cached since 0.02118s ago] ('Mom and Dad', 1945, 'William Beaudine', 80000000.0, 65000.0, 'United States')
# 2025-02-25 00:38:06,791 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,792 INFO sqlalchemy.engine.Engine [cached since 0.02158s ago] ("The Bells of St. Mary's", 1945, 'Leo McCarey', 11200000.0, 1600000.0, 'United States')
# 2025-02-25 00:38:06,792 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,792 INFO sqlalchemy.engine.Engine [cached since 0.02212s ago] ('Song of the South', 1946, 'Harve Foster\n\nWilfred Jackson', 65000000.0, 2125000.0, 'United States')
# 2025-02-25 00:38:06,792 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,793 INFO sqlalchemy.engine.Engine [cached since 0.02256s ago] ('The Best Years of Our Lives', 1946, 'William Wyler', 14750000.0, 2100000.0, 'United States')
# 2025-02-25 00:38:06,793 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,793 INFO sqlalchemy.engine.Engine [cached since 0.02293s ago] ('Duel in the Sun', 1946, 'King Vidor', 10000000.0, 5255000.0, 'United States')
# 2025-02-25 00:38:06,793 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,793 INFO sqlalchemy.engine.Engine [cached since 0.02331s ago] ('Forever Amber', 1947, 'Otto Preminger\nJohn M. Stahl', 8000000.0, 6375000.0, 'United States')
# 2025-02-25 00:38:06,794 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,794 INFO sqlalchemy.engine.Engine [cached since 0.0239s ago] ('Unconquered', 1947, 'Cecil B. DeMille', 7500000.0, 4200000.0, 'United States')
# 2025-02-25 00:38:06,794 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,795 INFO sqlalchemy.engine.Engine [cached since 0.02445s ago] ('Easter Parade', 1948, 'Charles Walters', 5918134.0, 2500000.0, 'United States')
# 2025-02-25 00:38:06,795 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,795 INFO sqlalchemy.engine.Engine [cached since 0.02488s ago] ('The Red Shoes', 1948, 'Michael Powell\nEmeric Pressburger', 5000000.0, 505581.0, 'United Kingdom')
# 2025-02-25 00:38:06,795 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,796 INFO sqlalchemy.engine.Engine [cached since 0.02553s ago] ('The Snake Pit', 1948, 'Anatole Litvak', 4100000.0, 3800000.0, 'United States')
# 2025-02-25 00:38:06,796 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,797 INFO sqlalchemy.engine.Engine [cached since 0.02654s ago] ('Samson and Delilah', 1949, 'Cecil B. DeMille', 14209250.0, 3097563.0, 'United States')
# 2025-02-25 00:38:06,797 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,797 INFO sqlalchemy.engine.Engine [cached since 0.02707s ago] ('Cinderella', 1950, 'Wilfred Jackson\nHamilton Luske\nClyde Geronimi', 263591415.0, 2200000.0, 'United States')
# 2025-02-25 00:38:06,797 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,797 INFO sqlalchemy.engine.Engine [cached since 0.02743s ago] ("King Solomon's Mines", 1950, 'Compton Bennett\nAndrew Marton', 10050000.0, 2258000.0, 'United States')
# 2025-02-25 00:38:06,798 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,798 INFO sqlalchemy.engine.Engine [cached since 0.02783s ago] ('Quo Vadis', 1951, 'Mervyn LeRoy', 21037000.0, 7623000.0, 'United States')
# 2025-02-25 00:38:06,798 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,798 INFO sqlalchemy.engine.Engine [cached since 0.0282s ago] ('This Is Cinerama', 1952, 'Mike Todd\nMichael Todd, Jr.\nWalter A. Thompson\nFred Rickey', 50000000.0, 1000000.0, 'United States')
# 2025-02-25 00:38:06,799 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,799 INFO sqlalchemy.engine.Engine [cached since 0.02868s ago] ('The Greatest Show on Earth', 1952, 'Cecil B. DeMille', 18350000.0, 3873946.0, 'United States')
# 2025-02-25 00:38:06,799 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,799 INFO sqlalchemy.engine.Engine [cached since 0.02906s ago] ('Peter Pan', 1953, 'Hamilton Luske\nClyde Geronimi\nWilfred Jackson', 145000000.0, 3000000.0, 'United States')
# 2025-02-25 00:38:06,799 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine [cached since 0.02952s ago] ('The Robe', 1953, 'Henry Koster', 25000000.0, 4100000.0, 'United States')
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine [cached since 0.02985s ago] ('Rear Window', 1954, 'Alfred Hitchcock', 24500000.0, 1000000.0, 'United States')
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine [cached since 0.03018s ago] ('White Christmas', 1954, 'Michael Curtiz', 26000050.0, 3800000.0, 'United States')
# 2025-02-25 00:38:06,800 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine [cached since 0.0305s ago] ('20,000 Leagues Under the Sea', 1954, 'Richard Fleischer', 25000134.0, 4500000.0, 'United States')
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine [cached since 0.03081s ago] ('Lady and the Tramp', 1955, 'Hamilton Luske\nClyde Geronimi\nWilfred Jackson', 187000000.0, 4000000.0, 'United States')
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine [cached since 0.03119s ago] ('Cinerama Holiday', 1955, 'Robert L. Bendick\nPhilippe De Lacy', 21000000.0, 2000000.0, 'United States')
# 2025-02-25 00:38:06,801 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,802 INFO sqlalchemy.engine.Engine [cached since 0.03152s ago] ('Mister Roberts', 1955, 'John Ford\nMervyn LeRoy\nJoshua Logan', 9900000.0, 2400000.0, 'United States')
# 2025-02-25 00:38:06,802 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,802 INFO sqlalchemy.engine.Engine [cached since 0.03195s ago] ('The Ten Commandments', 1956, 'Cecil B. DeMille', 90066230.0, 13270000.0, 'United States')
# 2025-02-25 00:38:06,802 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,802 INFO sqlalchemy.engine.Engine [cached since 0.03225s ago] ('The Bridge on the River Kwai', 1957, 'David Lean', 30600000.0, 2840000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,803 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,803 INFO sqlalchemy.engine.Engine [cached since 0.03268s ago] ('South Pacific', 1958, 'Joshua Logan', 30000000.0, 5610000.0, 'United States')
# 2025-02-25 00:38:06,803 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,803 INFO sqlalchemy.engine.Engine [cached since 0.03318s ago] ('Ben-Hur', 1959, 'William Wyler', 90000000.0, 15900000.0, 'United States')
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine [cached since 0.0336s ago] ('Swiss Family Robinson', 1960, 'Ken Annakin', 30000000.0, 4000000.0, 'United States')
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine [cached since 0.03396s ago] ('Spartacus', 1960, 'Stanley Kubrick', 60000000.0, 10284014.0, 'United States')
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,804 INFO sqlalchemy.engine.Engine [cached since 0.03431s ago] ('Psycho', 1960, 'Alfred Hitchcock', 50000000.0, 800000.0, 'United States')
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine [cached since 0.0347s ago] ('One Hundred and One Dalmatians', 1961, 'Wolfgang Reitherman\nHamilton Luske\nClyde Geronimi', 303000000.0, 3600000.0, 'United States')
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine [cached since 0.0351s ago] ('West Side Story', 1961, 'Robert Wise\nJerome Robbins', 105000000.0, 7000000.0, 'United States')
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,805 INFO sqlalchemy.engine.Engine [cached since 0.03543s ago] ('Lawrence of Arabia', 1962, 'David Lean', 77324852.0, 13800000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine [cached since 0.03574s ago] ('How the West Was Won', 1962, 'Henry Hathaway\nJohn Ford\nGeorge Marshall', 35000000.0, 14483000.0, 'United States')
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine [cached since 0.03605s ago] ('The Longest Day', 1962, 'Ken Annakin\n\nAndrew Marton\n\nBernhard Wicki', 33200000.0, 8600000.0, 'United States')
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,806 INFO sqlalchemy.engine.Engine [cached since 0.03638s ago] ('Cleopatra', 1963, 'Joseph L. Mankiewicz', 40300000.0, 31115000.0, 'United States')
# 2025-02-25 00:38:06,807 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,807 INFO sqlalchemy.engine.Engine [cached since 0.03674s ago] ('From Russia with Love', 1963, 'Terence Young', 78900000.0, 2000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,807 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,807 INFO sqlalchemy.engine.Engine [cached since 0.03703s ago] ('My Fair Lady', 1964, 'George Cukor', 55000000.0, 17000000.0, 'United States')
# 2025-02-25 00:38:06,807 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,808 INFO sqlalchemy.engine.Engine [cached since 0.03746s ago] ('Goldfinger', 1964, 'Guy Hamilton', 124900000.0, 3000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,808 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,808 INFO sqlalchemy.engine.Engine [cached since 0.03783s ago] ('Mary Poppins', 1964, 'Robert Stevenson', 44000000.0, 5200000.0, 'United States')
# 2025-02-25 00:38:06,808 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,808 INFO sqlalchemy.engine.Engine [cached since 0.03831s ago] ('The Sound of Music', 1965, 'Robert Wise', 286214076.0, 8000000.0, 'United States')
# 2025-02-25 00:38:06,809 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,809 INFO sqlalchemy.engine.Engine [cached since 0.03917s ago] ('The Bible: In the Beginning', 1966, 'John Huston', 25325000.0, 18000000.0, 'Italy\nUnited States')
# 2025-02-25 00:38:06,810 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,810 INFO sqlalchemy.engine.Engine [cached since 0.04001s ago] ('Hawaii', 1966, 'George Roy Hill', 34562222.0, 15000000.0, 'United States')
# 2025-02-25 00:38:06,810 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,811 INFO sqlalchemy.engine.Engine [cached since 0.04046s ago] ("Who's Afraid of Virginia Woolf?", 1966, 'Mike Nichols', 33736689.0, 7613000.0, 'United States')
# 2025-02-25 00:38:06,811 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,811 INFO sqlalchemy.engine.Engine [cached since 0.04089s ago] ('The Jungle Book', 1967, 'Wolfgang Reitherman', 378000000.0, 3900000.0, 'United States')
# 2025-02-25 00:38:06,811 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,811 INFO sqlalchemy.engine.Engine [cached since 0.04138s ago] ('The Graduate', 1967, 'Mike Nichols', 85000000.0, 3100000.0, 'United States')
# 2025-02-25 00:38:06,812 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,812 INFO sqlalchemy.engine.Engine [cached since 0.04185s ago] ('2001: A Space Odyssey', 1968, 'Stanley Kubrick', 141000000.0, 10300000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,812 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,812 INFO sqlalchemy.engine.Engine [cached since 0.04226s ago] ('Funny Girl', 1968, 'William Wyler', 80000000.0, 8800000.0, 'United States')
# 2025-02-25 00:38:06,813 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,813 INFO sqlalchemy.engine.Engine [cached since 0.04273s ago] ('Butch Cassidy and the Sundance Kid', 1969, 'George Roy Hill', 152308525.0, 6600000.0, 'United States')
# 2025-02-25 00:38:06,813 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,813 INFO sqlalchemy.engine.Engine [cached since 0.04311s ago] ('Love Story', 1970, 'Arthur Hiller', 173400000.0, 2260000.0, 'United States')
# 2025-02-25 00:38:06,813 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,814 INFO sqlalchemy.engine.Engine [cached since 0.04347s ago] ('The French Connection', 1971, 'William Friedkin', 75000000.0, 3300000.0, 'United States')
# 2025-02-25 00:38:06,814 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,814 INFO sqlalchemy.engine.Engine [cached since 0.04389s ago] ('Fiddler on the Roof', 1971, 'Norman Jewison', 49400000.0, 9000000.0, 'United States')
# 2025-02-25 00:38:06,814 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,814 INFO sqlalchemy.engine.Engine [cached since 0.04443s ago] ('Diamonds Are Forever', 1971, 'Guy Hamilton', 116000000.0, 7200000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,815 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,815 INFO sqlalchemy.engine.Engine [cached since 0.0448s ago] ('The Godfather', 1972, 'Francis Ford Coppola', 246120974.0, 6000000.0, 'United States')
# 2025-02-25 00:38:06,815 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,815 INFO sqlalchemy.engine.Engine [cached since 0.04524s ago] ('The Exorcist', 1973, 'William Friedkin', 430872776.0, 10000000.0, 'United States')
# 2025-02-25 00:38:06,815 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,816 INFO sqlalchemy.engine.Engine [cached since 0.04558s ago] ('The Sting', 1973, 'George Roy Hill', 115000000.0, 5500000.0, 'United States')
# 2025-02-25 00:38:06,816 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,816 INFO sqlalchemy.engine.Engine [cached since 0.04592s ago] ('The Towering Inferno', 1974, 'John Guillermin\nIrwin Allen', 203336412.0, 14300000.0, 'United States')
# 2025-02-25 00:38:06,816 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,816 INFO sqlalchemy.engine.Engine [cached since 0.04633s ago] ('Jaws', 1975, 'Steven Spielberg', 477220580.0, 9000000.0, 'United States')
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine [cached since 0.04664s ago] ('Rocky', 1976, 'John G. Avildsen', 225000000.0, 1075000.0, 'United States')
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine [cached since 0.04694s ago] ('Star Wars', 1977, 'George Lucas', 775398007.0, 11293151.0, 'United States')
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,817 INFO sqlalchemy.engine.Engine [cached since 0.04735s ago] ('Grease', 1978, 'Randal Kleiser', 396271103.0, 6000000.0, 'United States')
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine [cached since 0.04768s ago] ('Moonraker', 1979, 'Lewis Gilbert', 210308099.0, 31000000.0, 'United Kingdom\nUnited States\nFrance')
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine [cached since 0.04799s ago] ('Rocky II', 1979, 'Sylvester Stallone', 200182160.0, 7000000.0, 'United States')
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine [cached since 0.04828s ago] ('The Empire Strikes Back', 1980, 'Irvin Kershner', 550016086.0, 23000000.0, 'United States')
# 2025-02-25 00:38:06,818 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine [cached since 0.04859s ago] ('Raiders of the Lost Ark', 1981, 'Steven Spielberg', 389925971.0, 18000000.0, 'United States')
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine [cached since 0.04894s ago] ('E.T. the Extra-Terrestrial', 1982, 'Steven Spielberg', 797307407.0, 10500000.0, 'United States')
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine [cached since 0.04921s ago] ('Return of the Jedi', 1983, 'Richard Marquand', 482466382.0, 32500000.0, 'United States')
# 2025-02-25 00:38:06,819 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine [cached since 0.04955s ago] ('Ghostbusters', 1984, 'Ivan Reitman', 370000000.0, 25000000.0, 'United States')
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine [cached since 0.04987s ago] ('Back to the Future', 1985, 'Robert Zemeckis', 389225789.0, 19000000.0, 'United States')
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine [cached since 0.05018s ago] ('Top Gun', 1986, 'Tony Scott', 357288178.0, 14000000.0, 'United States')
# 2025-02-25 00:38:06,820 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine [cached since 0.0506s ago] ('Fatal Attraction', 1987, 'Adrian Lyne', 320145693.0, 14000000.0, 'United States')
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine [cached since 0.0509s ago] ('Rain Man', 1988, 'Barry Levinson', 354825435.0, 30000000.0, 'United States')
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine [cached since 0.05124s ago] ('Indiana Jones and the Last Crusade', 1989, 'Steven Spielberg', 474171806.0, 36000000.0, 'United States')
# 2025-02-25 00:38:06,821 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,822 INFO sqlalchemy.engine.Engine [cached since 0.05155s ago] ('Ghost', 1990, 'Jerry Zucker', 505870681.0, 22000000.0, 'United States')
# 2025-02-25 00:38:06,822 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,822 INFO sqlalchemy.engine.Engine [cached since 0.05194s ago] ('Terminator 2: Judgment Day', 1991, 'James Cameron', 523774456.0, 94000000.0, 'United States')
# 2025-02-25 00:38:06,822 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,822 INFO sqlalchemy.engine.Engine [cached since 0.05233s ago] ('Aladdin', 1992, 'John Musker\nRon Clements', 504050219.0, 28000000.0, 'United States')
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine [cached since 0.05263s ago] ('Jurassic Park', 1993, 'Steven Spielberg', 1037535230.0, 63000000.0, 'United States')
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine [cached since 0.05298s ago] ('The Lion King', 1994, 'Roger Allers\nRob Minkoff', 970707763.0, 45000000.0, 'United States')
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,823 INFO sqlalchemy.engine.Engine [cached since 0.05332s ago] ('Toy Story', 1995, 'John Lasseter', 373554033.0, 30000000.0, 'United States')
# 2025-02-25 00:38:06,824 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,824 INFO sqlalchemy.engine.Engine [cached since 0.05369s ago] ('Die Hard with a Vengeance', 1995, 'John McTiernan', 366101666.0, 70000000.0, 'United States')
# 2025-02-25 00:38:06,824 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,824 INFO sqlalchemy.engine.Engine [cached since 0.05425s ago] ('Independence Day', 1996, 'Roland Emmerich', 817400891.0, 75000000.0, 'United States')
# 2025-02-25 00:38:06,825 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,827 INFO sqlalchemy.engine.Engine [cached since 0.05708s ago] ('Titanic', 1997, 'James Cameron', 2257844554.0, 200000000.0, 'United States')
# 2025-02-25 00:38:06,828 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,829 INFO sqlalchemy.engine.Engine [cached since 0.0585s ago] ('Armageddon', 1998, 'Michael Bay', 553709788.0, 140000000.0, 'United States')
# 2025-02-25 00:38:06,829 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,829 INFO sqlalchemy.engine.Engine [cached since 0.05903s ago] ('Star Wars: Episode I – The Phantom Menace', 1999, 'George Lucas', 1046515409.0, 115000000.0, 'United States')
# 2025-02-25 00:38:06,829 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,830 INFO sqlalchemy.engine.Engine [cached since 0.0595s ago] ('Mission: Impossible 2', 2000, 'John Woo', 546388108.0, 100000000.0, 'United States\nGermany')
# 2025-02-25 00:38:06,830 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,830 INFO sqlalchemy.engine.Engine [cached since 0.05993s ago] ("Harry Potter and the Philosopher's Stone", 2001, 'Chris Columbus', 1009046830.0, 125000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,830 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,830 INFO sqlalchemy.engine.Engine [cached since 0.0604s ago] ('The Lord of the Rings: The Two Towers', 2002, 'Peter Jackson', 948945489.0, 94000000.0, 'New Zealand\nUnited States')
# 2025-02-25 00:38:06,831 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,831 INFO sqlalchemy.engine.Engine [cached since 0.06084s ago] ('The Lord of the Rings: The Return of the King', 2003, 'Peter Jackson', 1147997407.0, 94000000.0, 'New Zealand\nGermany\nUnited States')
# 2025-02-25 00:38:06,831 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,831 INFO sqlalchemy.engine.Engine [cached since 0.06123s ago] ('Shrek 2', 2004, 'Andrew Adamson\nKelly Asbury\nConrad Vernon', 932530034.0, 150000000.0, 'United States')
# 2025-02-25 00:38:06,831 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,832 INFO sqlalchemy.engine.Engine [cached since 0.06158s ago] ('Harry Potter and the Goblet of Fire', 2005, 'Mike Newell', 896346413.0, 150000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,832 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,832 INFO sqlalchemy.engine.Engine [cached since 0.06205s ago] ("Pirates of the Caribbean: Dead Man's Chest", 2006, 'Gore Verbinski', 1066179747.0, 225000000.0, 'United States')
# 2025-02-25 00:38:06,832 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,832 INFO sqlalchemy.engine.Engine [cached since 0.06236s ago] ("Pirates of the Caribbean: At World's End", 2007, 'Gore Verbinski', 960996492.0, 300000000.0, 'United States')
# 2025-02-25 00:38:06,833 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,833 INFO sqlalchemy.engine.Engine [cached since 0.06279s ago] ('The Dark Knight', 2008, 'Christopher Nolan', 1007336937.0, 185000000.0, 'United States\nUnited Kingdom')
# 2025-02-25 00:38:06,833 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,833 INFO sqlalchemy.engine.Engine [cached since 0.06325s ago] ('Avatar', 2009, 'James Cameron', 2923706026.0, 237000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,833 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,834 INFO sqlalchemy.engine.Engine [cached since 0.0636s ago] ('Toy Story 3', 2010, 'Lee Unkrich', 1066970811.0, 200000000.0, 'United States')
# 2025-02-25 00:38:06,834 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,834 INFO sqlalchemy.engine.Engine [cached since 0.06412s ago] ('Harry Potter and the Deathly Hallows – Part 2', 2011, 'David Yates', 1342139727.0, 250000000.0, 'United Kingdom\nUnited States')
# 2025-02-25 00:38:06,835 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,835 INFO sqlalchemy.engine.Engine [cached since 0.06472s ago] ('The Avengers', 2012, 'Joss Whedon', 1518815515.0, 220000000.0, 'United States')
# 2025-02-25 00:38:06,835 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,835 INFO sqlalchemy.engine.Engine [cached since 0.06513s ago] ('Frozen', 2013, 'Chris Buck\nJennifer Lee', 1290000000.0, 150000000.0, 'United States')
# 2025-02-25 00:38:06,835 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine [cached since 0.06551s ago] ('Transformers: Age of Extinction', 2014, 'Michael Bay', 1104039076.0, 210000000.0, 'United States')
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine [cached since 0.06584s ago] ('Star Wars: The Force Awakens', 2015, 'J. J. Abrams', 2068223624.0, 245000000.0, 'United States')
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine [cached since 0.0662s ago] ('Captain America: Civil War', 2016, 'Anthony Russo\nJoe Russo', 1153337496.0, 250000000.0, 'United States')
# 2025-02-25 00:38:06,836 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,837 INFO sqlalchemy.engine.Engine [cached since 0.06648s ago] ('Star Wars: The Last Jedi', 2017, 'Rian Johnson', 1332539889.0, 200000000.0, 'United States')
# 2025-02-25 00:38:06,837 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,837 INFO sqlalchemy.engine.Engine [cached since 0.0669s ago] ('Avengers: Infinity War', 2018, 'Anthony Russo\nJoe Russo', 2048359754.0, 316000000.0, 'United States')
# 2025-02-25 00:38:06,837 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,837 INFO sqlalchemy.engine.Engine [cached since 0.06733s ago] ('Avengers: Endgame', 2019, 'Anthony Russo\nJoe Russo', 2797501328.0, 356000000.0, 'United States')
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine [cached since 0.06772s ago] ('Demon Slayer: Mugen Train', 2020, 'Haruo Sotozaki', 507119058.0, 15750000.0, 'Japan')
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine [cached since 0.06804s ago] ('Spider-Man: No Way Home', 2021, 'Jon Watts', 1922598800.0, 200000000.0, 'United States')
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,838 INFO sqlalchemy.engine.Engine [cached since 0.06837s ago] ('Avatar: The Way of Water', 2022, 'James Cameron', 2320250281.0, 350000000.0, 'United States')
# 2025-02-25 00:38:06,839 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,839 INFO sqlalchemy.engine.Engine [cached since 0.0687s ago] ('Barbie', 2023, 'Greta Gerwig', 1447038421.0, 128000000.0, 'United States\nUnited Kingdom')
# 2025-02-25 00:38:06,839 INFO sqlalchemy.engine.Engine INSERT INTO films_data (title, release_year, director, box_office, budget, country) VALUES (?, ?, ?, ?, ?, ?)
# 2025-02-25 00:38:06,839 INFO sqlalchemy.engine.Engine [cached since 0.069s ago] ('Inside Out 2', 2024, 'Kelsey Mann', 1698863816.0, 200000000.0, 'United States')
# 2025-02-25 00:38:06,840 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/m0/9dr3jfm12bj1fkg2xjqh62jc0000gn/T/ipykernel_8103/670517983.py:3: MovedIn20Warning: Deprecated API features detected! These feature(s) are not compatible with SQLAlchemy 2.0. To prevent incompatible upgrades prior to updating applications, ensure requirements files are pinned to "sqlalchemy<2.0". Set environment variable SQLALCHEMY_WARN_20=1 to show all deprecation warnings.  Set environment variable SQLALCHEMY_SILENCE_UBER_WARNING=1 to silence this message. (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %% [markdown]
# ## Export of the database content to a JSON file for further visualization

# %%
# Querying all film records from the database
films = session.query(Film).all()

# Creating a list of dictionaries to store film data
films_data = [{
    'id': film.id,
    'title': film.title,
    'release_year': film.release_year,
    'director': film.director,
    'box_office': float(film.box_office),
    'budget': float(film.budget),
    'country': film.country
} for film in films]

# Writing the films data to a JSON file
with open('highest_grossing_films.json', 'w') as json_file:
    json.dump(films_data, json_file, indent=4)

# Closing the session
session.close()
# Out:
# 2025-02-25 00:38:10,271 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-02-25 00:38:10,275 INFO sqlalchemy.engine.Engine SELECT films_data.id AS films_data_id, films_data.title AS films_data_title, films_data.release_year AS films_data_release_year, films_data.director AS films_data_director, films_data.box_office AS films_data_box_office, films_data.budget AS films_data_budget, films_data.country AS films_data_country
# FROM films_data
# 2025-02-25 00:38:10,275 INFO sqlalchemy.engine.Engine [generated in 0.00079s] ()
# 2025-02-25 00:38:10,284 INFO sqlalchemy.engine.Engine ROLLBACK
